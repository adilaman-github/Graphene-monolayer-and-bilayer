# %%
import numpy as np
from decimal import Decimal
import json

sample_number = 100
i=0
d=[]
result=0
while i<sample_number:
    
    f = open('/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB/t4[zero]/Energy_Eigenvalues_w[1.00]_t4[zero]/Energy_Eigenvalues'+str(i)+'.txt','r')
    x=f.read().splitlines()
    #print(x)
    #myList = ast.literal_eval(x)
    j=0
    c=[]
    while j<len(x):
        cc=Decimal(x[j])
        #print(cc)
        c.append(cc)
        j=j+1
    #print(c)
    #result = result + c
    d.append(c)
    #print("\n")
    #f.close()
    i=i+1
#print("*******")
#print(d)
tt=np.sum(d, axis=0)
tt=np.true_divide(tt,sample_number)
#print(tt)
np.savetxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.00].txt",tt,fmt='%.54e')

# %%
# %matplotlib

import numpy as np
import matplotlib.pyplot as plt

j=0

fig, ((ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=2, ncols=2)
st = fig.suptitle("Density of States, Lattice size: 7200", fontsize="x-large")


x=-5.5
xx=[x]
yy1=[]
yy2=[]
yy3=[]
yy4=[]
yy5=[]
yy6=[]
yy7=[]
yy8=[]

k=0
n= 12.5*(11) #1/0.08=12.5 number of slots and 0.04 bin size
while k<n:
    #if x == 3.0:
    #    break
    x = x + 0.08
    z = round(x,3)
    xx.append(z)
    k=k+1

#tt=np.loadtxt('/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues0.txt') 
tt1 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.25].txt")
tt2 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.50].txt")
tt3 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.75].txt")
tt4 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.00].txt")
tt5 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.50].txt")
tt6 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.25].txt")
tt7 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.75].txt")
#tt8 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_SingleLayer_Chirality_Average/Result_t[2.00]")

#print(tt)
#xx = np.logspace(start=np.log10(10**(-5)), stop=np.log10(1), num=40)

while j<len(xx)-1:
    
    da = xx[j]
    db = xx[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d1 = len([x for x in tt1 if x > da and x < db])
    d2 = len([x for x in tt2 if x > da and x < db])
    d3 = len([x for x in tt3 if x > da and x < db])
    d4 = len([x for x in tt4 if x > da and x < db])
    d5 = len([x for x in tt5 if x > da and x < db])
    d6 = len([x for x in tt6 if x > da and x < db])
    d7 = len([x for x in tt7 if x > da and x < db])
    #d8 = len([x for x in tt8 if x > da and x < db])
    
    yy1.append(d1)
    yy2.append(d2)
    yy3.append(d3)
    yy4.append(d4)
    yy5.append(d5)
    yy6.append(d6)
    yy7.append(d7)
    #yy8.append(d8)
    
    #print(d)
    #sum(d1 < x < d2 for x in E)
    #x=-np.log(np.log(1/E[j]))
    #g=d*E[j]
#    x = x + (0.04)/2
#    xx.append(x)
 #   y = d
    #print((x,y))
    #xx.append(x)
    #yy.append(d)
    #plt.scatter(x,y,s=2,c="b")
    j=j+1

#print(xx)
#print(yy)

#a = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11,20, 51, 5, 79, 31, 27]) 
  
# Creating histogram 
#result1=result1
#fig, ax = plt.subplots(figsize =(10, 7)) 


#values, bins, _ = plt.hist(tt, bins = xx, histtype="step", density = True, label = 'w=0.25')
#plt.hist(tt1, bins = xx, histtype="step", density = True, label = "w=0.25") 
#plt.hist(tt2, bins = xx, histtype="step", density = True, label = "w=0.50")
#plt.hist(tt3, bins = xx, histtype="step", density = True, label = "w=0.75")
#plt.hist(tt4, bins = xx, histtype="step", density = True, label = "w=1.00")
#plt.hist(tt5, bins = xx, histtype="step", density = True, label = "w=1.50")
#plt.hist(tt6, bins = xx, histtype="step", density = True, label = "w=1.25")
#plt.hist(tt7, bins = xx, histtype="step", density = True, label = "w=1.75")

#ax0.hist(tt1, bins = xx, histtype="step", density = True, label = "w=0.25") 
#ax0.set_title('w=0.25')
#ax0.set_xlabel('Energy')
#ax0.set_ylabel('Number of states')

#ax1.hist(tt2, bins = xx, histtype="step", density = True, label = "w=0.50") 
#ax1.set_title('w=0.50')
#ax1.set_xlabel('Energy')
#ax1.set_ylabel('Number of states')

#ax2.hist(tt3, bins = xx, histtype="step", density = True, label = "w=0.75")
#ax2.set_title('w=0.75')
#ax2.set_xlabel('Energy')
#ax2.set_ylabel('Number of states')

ax3.hist(tt4, bins = xx, histtype="step", density = True, label = "w=1.00") 
ax3.set_title('w=1.00')
ax3.set_xlabel('Energy')
ax3.set_ylabel('Number of states')

ax4.hist(tt5, bins = xx, histtype="step", density = True, label = "w=1.50")
ax4.set_title('w=1.50')
ax4.set_xlabel('Energy')
ax4.set_ylabel('Number of states')

ax5.hist(tt6, bins = xx, histtype="step", density = True, label = "w=1.25") 
ax5.set_title('w=1.25')
ax5.set_xlabel('Energy')
ax5.set_ylabel('Number of states')

ax6.hist(tt7, bins = xx, histtype="step", density = True, label = "w=1.75")
ax6.set_title('w=1.75')
ax6.set_xlabel('Energy')
ax6.set_ylabel('Number of states')

#plt.hist(tt8, bins = xx, alpha=0.5, density = True, label = "w=2.00") 


#plt.xlabel('Energy')
#plt.ylabel('Number of states')
#plt.title("Density of States, Lattice size: 7200")
#plt.legend(loc='upper right')

#area = sum(np.diff(bins)*values)
# Show plot 
#fig.tight_layout()
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib

import matplotlib.pyplot as plt
import numpy as np
import math

tt = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.25].txt")
#print(tt)
i=0
result=[]
while i<len(tt):
    #print(result1[i])
    if (tt[i]>=0 and tt[i]<1):
        #print(tt[i])
        result.append(tt[i])
    i=i+1
#print(result)

result = [i for i in result if i != 0]
#print(result)

i=0
rt=[]
while i<len(result):
    #x = -math.log(math.log(1/result[i])) #Dyson form
    x = -(math.log(1/result[i])) #Gade wegner
    rt.append(x)
    i=i+1
#print(rt)

#print(result)

i=0
xx=[]
d=0
num = 20
while i<num:
    d = d+ 0.03
    xx.append(d)
    i=i+1
p=sorted(xx)
#print(p)

j=0
yy=[]
while j<len(p)-1:
    d1 = p[j]
    d2 = p[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result if x >= d1 and x <= d2])
    #print(d)
    dd= d1*d 
    #print(dd)
    ddd = np.log(dd)
    #print("**")
    #print(ddd)
    yy.append(ddd)
    j=j+1
#print(yy)
f=rt[:19]
#print(f)

#i=1
#while i<4:
#    f.pop(i)
#    yy.pop(i)
#    i=i+1
#del f[1:4]
#del yy[1:4]
#print(f)
plt.xlabel('-(ln(1/E))')
plt.ylabel(r'$ln(E \rho (E))$')
plt.title("Density of States,Gade Wegner, w = 0.25, t4=0, sample size 7200")
#plt.scatter(f,yy,s=5,c="black")
#plt.plot(f,yy)
#plt.show()



# calculate polynomial
z = np.polyfit(f, yy, 1)
fd = np.poly1d(z)

# calculate new x's and y's
x_new = np.linspace(f[0], f[-1], 50)
y_new = fd(x_new)

plt.plot(f,yy,'x', x_new, y_new,markersize=5)
#plt.errorbar(f, yy, yerr=error_array)

#plt.xlim([f[0]-1, f[-1] + 1 ])
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib

import matplotlib.pyplot as plt
import numpy as np
import math
from decimal import Decimal
import json
from operator import truediv



tt1 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[0.25].txt")
tt2 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[0.50].txt")
tt3 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[0.75].txt")
tt4 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[1.00].txt")
tt5 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[1.50].txt")

#print(tt)

i=0
result1=[]
while i<len(tt1):
    #print(result1[i])
    if (tt1[i]>=0 and tt1[i]<1):
        #print(tt[i])
        result1.append(tt1[i])
    i=i+1
#print(result)

result1 = [i for i in result1 if i != 0]
#print(len(result1))

i=0
result2=[]
while i<len(tt2):
    #print(result1[i])
    if (tt2[i]>=0 and tt2[i]<1):
        #print(tt[i])
        result2.append(tt2[i])
    i=i+1
#print(result)

result2 = [i for i in result2 if i != 0]
#print(result)


i=0
result3=[]
while i<len(tt3):
    #print(result1[i])
    if (tt3[i]>=0 and tt3[i]<1):
        #print(tt[i])
        result3.append(tt3[i])
    i=i+1
#print(result)

result3 = [i for i in result3 if i != 0]
#print(result)


i=0
result4=[]
while i<len(tt4):
    #print(result1[i])
    if (tt4[i]>=0 and tt4[i]<1):
        #print(tt[i])
        result4.append(tt4[i])
    i=i+1
#print(result)

result4 = [i for i in result4 if i != 0]
#print(result)


i=0
result5=[]
while i<len(tt5):
    #print(result1[i])
    if (tt5[i]>=0 and tt5[i]<1):
        #print(tt[i])
        result5.append(tt5[i])
    i=i+1
#print(result)

result5 = [i for i in result5 if i != 0]
#print(result)



pp5=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp5)-1:
    diff = pp5[i+1]-pp5[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p5=[]
i=0
d=0
while i<len(xxi)-1:
    p5.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p5)

pp4=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp4)-1:
    diff = pp4[i+1]-pp4[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p4=[]
i=0
d=0
while i<len(xxi)-1:
    p4.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p4)

pp3=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp3)-1:
    diff = pp3[i+1]-pp3[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p3=[]
i=0
d=0
while i<len(xxi)-1:
    p3.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p3)


pp2=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp2)-1:
    diff = pp2[i+1]-pp2[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p2=[]
i=0
d=0
while i<len(xxi)-1:
    p2.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p2)


pp1=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp1)-1:
    diff = pp1[i+1]-pp1[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p1=[]
i=0
d=0
while i<len(xxi)-1:
    p1.append(d)
    d=d+xxi[i]
    i=i+1
#print(p1)


j=0
yy1=[]
while j<len(p1)-1:
    d1 = p1[j]
    d2 = p1[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result1 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy1.append(d)
    j=j+1
#print(len(yy1))

j=0
yy2=[]
while j<len(p2)-1:
    d1 = p2[j]
    d2 = p2[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result2 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy2.append(d)
    j=j+1
#print(yy)

j=0
yy3=[]
while j<len(p3)-1:
    d1 = p3[j]
    d2 = p3[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result3 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy3.append(d)
    j=j+1
#print(yy)

j=0
yy4=[]
while j<len(p4)-1:
    d1 = p4[j]
    d2 = p4[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result4 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy4.append(d)
    j=j+1
#print(len(yy4))

j=0
yy5=[]
while j<len(p5)-1:
    d1 = p5[j]
    d2 = p5[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result5 if x >= d1 and x <= d2])
    #print(d)
    #dd = (d*p[j])
    yy5.append(d)
    j=j+1
#print(len(yy5))
p1=np.delete(p1,-1)
p2=np.delete(p2,-1)
p3=np.delete(p3,-1)
p4=np.delete(p4,-1)
p5=np.delete(p5,-1)
#print(yy1)
sample_number=100

ii=0
f1=yy1[0:24]
lt = len(f1)
error1 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x1 = np.loadtxt('/home/lucifer/IISER/Summer_2021/t[0]/Energy_Eigenvalues_w[0.25]_t[0]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x1):
        if (x1[i]>=0 and x1[i]<1):
            result.append(x1[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p1)-1:
        d1 = p1[j]
        d2 = p1[j+1] #np.log(4+np.log(j))
        d = len([x for x in result if x >= d1 and x <= d2])
        yyi.append(d)
        j=j+1
    
    #print(yyi)
    #print(len(f))
    f2=yyi[0:24]
    error1 = error1 + (np.subtract(f1,f2))**2
    
    ii=ii+1



error1 = np.sqrt(error1)
error1 = np.true_divide(error1,math.sqrt(sample_number))
print(error1)
#print("\n")
#print(mean)
final_error1=list(map(truediv,error1,f1))
print(final_error1)
# Out:
# Using matplotlib backend: Qt5Agg
# [0.38729833 0.41231056 0.41231056 0.41231056 0.46904158 0.74161985
#  0.83066239 0.9539392  1.04880885 0.92195445 0.85440037 0.91104336
#  0.86023253 1.0198039  0.91651514 0.99498744 1.09544512 1.15325626
#  0.83666003 0.85440037 1.14455231 1.05830052 1.00995049 0.88881944]
# [0.3872983346207417, 0.41231056256176607, 0.41231056256176607, 0.10307764064044152, 0.15634719199411432, 0.2472066162365221, 0.1661324772583615, 0.15898986690282427, 0.2622022120425379, 0.13170777796132696, 0.122057196361679, 0.15184055965240498, 0.12289036095775181, 0.1456862718169367, 0.10183501544346311, 0.1243734296383275, 0.15649215928719032, 0.11532562594670796, 0.09296222517045284, 0.09493337494797255, 0.14306903927824496, 0.10583005244258363, 0.10099504938362078, 0.0888819441731559]

# %%
# %matplotlib

import matplotlib.pyplot as plt
import numpy as np
import math
from decimal import Decimal
import json
from operator import truediv

from scipy.optimize import curve_fit

plt.grid(True, which="both", ls="-",linewidth = "0.25")

xxi=np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Analysis_Results/Single_Layer_Chiral/xi_[1.00].txt")
yy=np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Analysis_Results/Single_Layer_Chiral/yi_[1.00].txt")

xxi_counter=np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Analysis_Results/Single_Layer_Chiral/xi_[1.00]_counter.txt")   
fit_y=np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Analysis_Results/Single_Layer_Chiral/yi_[1.00]_fit.txt")
error1=np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Analysis_Results/Single_Layer_Chiral/yerror_[1.00].txt")

error1[-1]=0
error1[-2] = 0
error1[-3] = 0
error1[-4] = 0
error1[-5] = 0

plt.xlabel(r'$\Gamma$')
plt.ylabel(r'$N(\Gamma)$')
plt.title("Density of States, Graphene Single Layer, w = 1.00, Lattice Size: 9216, Sample Size: 1000")


plt.scatter(xxi,yy, s=1.75,c='blue')
plt.plot(xxi_counter, fit_y, '--', color ='red', label ="optimized data")
plt.errorbar(xxi, yy,yerr = error1,fmt='.k',markersize=5,capsize=4,elinewidth=1.5, alpha=0.25)


plt.xlim([4*10**-2, 4])

plt.xscale('log')
plt.yscale('log')

plt.show()
# Out:
# Using matplotlib backend: Qt5Agg
