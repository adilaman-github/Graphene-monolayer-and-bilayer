# %%
# %matplotlib
import json
import matplotlib.pyplot as plt
import numpy as np

#Analysis
j=0

x=-4
xx=[x]
yy=[]
yy1=[]
yy2=[]
yy3=[]
yy4=[]
yy5=[]
yy6=[]
yy7=[]
yy8=[]
k=0
n= 12.5*(8) #1/0.08=12.5 number of slots and 0.04 bin size
while k<n:
    #if x == 3.0:
    #    break
    x = x + 0.08
    z = round(x,3)
    xx.append(z)
    k=k+1

    
# Normalising
#u = []
#for xx in xx:
    #u.append(xx / length)    
W1=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Energy_Eigenvalues-monolayer7569.txt')
W2=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Energy_Eigenvalues-AB_Algo17442.txt')
W3=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Energy_Eigenvalues-0.82.txt')
W4=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Energy_Eigenvalues-1.08.txt')
W5=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Energy_Eigenvalues-1.79.txt')
W8=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Energy_Eigenvalues0.txt')
W6=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Mono_Energy_Eigenvalues.txt')
W7=np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Mono_Energy_Eigenvalues.txt')


while j<len(xx)-1:
    da = xx[j]
    db = xx[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d1 = len([x for x in W1 if x > da and x < db])
    d2 = len([x for x in W2 if x > da and x < db])
    d3 = len([x for x in W3 if x > da and x < db])
    d4 = len([x for x in W4 if x > da and x < db])
    d5 = len([x for x in W5 if x > da and x < db])
    d6 = len([x for x in W6 if x > da and x < db])
    d7 = len([x for x in W7 if x > da and x < db])
    d8 = len([x for x in W8 if x > da and x < db])
    #d3 = len([x for x in W3 if x > da and x < db])
    #yy.append(d)
    yy1.append(d1)
    yy2.append(d2)
    yy3.append(d3)
    yy4.append(d4)
    yy5.append(d5)
    yy6.append(d6)
    yy7.append(d7)
    yy8.append(d8)
    #print(d)
    #sum(d1 < x < d2 for x in E)
    #x=-np.log(np.log(1/E[j]))
    #g=d*E[j]
#    x = x + (0.04)/2
#    xx.append(x)
 #   y = d
    #print((x,y))
    #xx.append(x)
    #yy.append(d)
    #plt.scatter(x,y,s=2,c="b")
    j=j+1

#print(xx)
#print(yy)

#a = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11,20, 51, 5, 79, 31, 27]) 
  
# Creating histogram 
#result1=result1
#fig, ax = plt.subplots(figsize =(10, 7)) 
plt.xlabel('Energy')
plt.ylabel('Number of states')
plt.title("Density of States, No Disorder, Lattice sites: 7442")
#plt.hist(W1, bins = xx, histtype="step",density ="True",label="MonoLayer")
#plt.hist(W2, bins = xx, histtype="step",density ="True",label="Bilayer AB 0 twist Algo 1") 
plt.hist(W3, bins = xx, histtype="step",density ="True",label="Bilayer AB 0.82 twist") 
plt.hist(W4, bins = xx, histtype="step",density ="True",label="Bilayer AB 1.08 twist") 
plt.hist(W5, bins = xx, histtype="step",density ="True",label="Bilayer AB 1.79 twist") 
#plt.hist(W6, bins = xx, histtype="step",density ="True",label="Monolayer Algo 2")
#plt.hist(W7, bins = xx, histtype="step",density ="True",label="Monolayer Algo 1") 
plt.hist(W8, bins = xx, histtype="step",density ="True",label="Bilayer AB 0 twist Algo 2") 



#plt.hist(W4, bins = xx, histtype="step",density ="True",label="1.08") 
#plt.hist(W5, bins = xx, histtype="step",density ="True",label="1.79") 


plt.legend(loc='upper right')

#plt.hist(W3, bins = xx, histtype="step") 

#area = sum(np.diff(bins)*values)
#print(values)
#print(area)
#print(bins)
#print(result1)
#print(xx)
#print(yy)
# Show plot 
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg
