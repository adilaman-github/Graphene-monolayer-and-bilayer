# %%
import numpy as np
from decimal import Decimal
import json

sample_number = 100
i=0
d=[]
result=0
while i<sample_number:
    
    f = open('/home/lucifer/IISER/SEM_7/Semester_Project/AA_AB/Graphene_Bilayer_AA/Energy_Eigenvalues_w[1.75]/Energy_Eigenvalues'+str(i)+'.txt','r')
    #f = open('/home/lucifer/IISER/SEM_7/Semester_Project/t4_Scale/t4[non_zero]/Energy_Eigenvalues_w[0.25]_t4[non_zero]/Energy_Eigenvalues'+str(i)+'.txt','r')
    #f = open('/home/lucifer/IISER/Summer_2021/t[0.01]/Energy_Eigenvalues_w[1.75]_t[0.01]/Energy_Eigenvalues'+str(i)+'.txt','r')
    x=f.read().splitlines()
    #print(x)
    #myList = ast.literal_eval(x)
    j=0
    c=[]
    while j<len(x):
        cc=Decimal(x[j])
        #print(cc)
        c.append(cc)
        j=j+1
    #print(c)
    #result = result + c
    d.append(c)
    #print("\n")
    #f.close()
    i=i+1
#print("*******")
#print(d)
tt=np.sum(d, axis=0)
tt=np.true_divide(tt,sample_number)
#print(tt)
np.savetxt("/home/lucifer/IISER/SEM_7/Semester_Project/AA_AB/Graphene_Bilayer_AA/Result_t[1.75].txt",tt,fmt='%.54e')

# %%
# %matplotlib

import numpy as np
import matplotlib.pyplot as plt

j=0

#fig, ((ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=2, ncols=2)
#st = fig.suptitle("Density of States, Lattice size: 7200", fontsize="x-large")


x=-7
xx=[]
yy=[]
yy1=[]
yy2=[]
yy3=[]
yy4=[]
yy5=[]
yy6=[]
yy7=[]
yy8=[]

k=0
n= 12.5*(14) #1/0.08=12.5 number of slots and 0.04 bin size
while k<n:
    #if x == 3.0:
    #    break
    x = x + 0.08
    z = round(x,3)
    xx.append(z)
    k=k+1

#tt=np.loadtxt('/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues0.txt') 
tt1 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[0.25].txt")
tt2 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[0.50].txt")
tt3 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[0.75].txt")
tt4 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[1.00].txt")
tt5 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[1.50].txt")
tt6 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[1.25].txt")
tt7 = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]/Result_t[1.75].txt")
#tt8 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_SingleLayer_Chirality_Average/Result_t[2.00]")

#print(tt)
#xx = np.logspace(start=np.log10(10**(-5)), stop=np.log10(1), num=40)

while j<len(xx)-1:
    
    da = xx[j]
    db = xx[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    #d = len([x for x in tt if x <da])
    d1 = len([x for x in tt1 if x > da and x < db])
    d2 = len([x for x in tt2 if x > da and x < db])
    d3 = len([x for x in tt3 if x > da and x < db])
    d4 = len([x for x in tt4 if x > da and x < db])
    d5 = len([x for x in tt5 if x > da and x < db])
    d6 = len([x for x in tt6 if x > da and x < db])
    d7 = len([x for x in tt7 if x > da and x < db])
    #d8 = len([x for x in tt8 if x > da and x < db])
    
    #yy.append(d)
    yy1.append(d1)
    yy2.append(d2)
    yy3.append(d3)
    yy4.append(d4)
    yy5.append(d5)
    yy6.append(d6)
    yy7.append(d7)
    #yy8.append(d8)
    
    #print(d)
    #sum(d1 < x < d2 for x in E)
    #x=-np.log(np.log(1/E[j]))
    #g=d*E[j]
#    x = x + (0.04)/2
#    xx.append(x)
 #   y = d
    #print((x,y))
    #xx.append(x)
    #yy.append(d)
    #plt.scatter(x,y,s=2,c="b")
    j=j+1

#print(xx)
#print(yy)

#a = np.array([22, 87, 5, 43, 56, 73, 55, 54, 11,20, 51, 5, 79, 31, 27]) 
  
# Creating histogram 
#result1=result1
#fig, ax = plt.subplots(figsize =(10, 7)) 


#values, bins, _ = plt.hist(tt, bins = xx, histtype="step", density = True, label = 'w=0.25')
#plt.hist(tt, bins = xx, histtype="step", density = True, label = "w=1.50")
plt.hist(tt1, bins = xx, histtype="step", density = True, label = "w=0.25") 
plt.hist(tt2, bins = xx, histtype="step", density = True, label = "w=0.50")
plt.hist(tt3, bins = xx, histtype="step", density = True, label = "w=0.75")
plt.hist(tt4, bins = xx, histtype="step", density = True, label = "w=1.00")
plt.hist(tt5, bins = xx, histtype="step", density = True, label = "w=1.50")
plt.hist(tt6, bins = xx, histtype="step", density = True, label = "w=1.25")
plt.hist(tt7, bins = xx, histtype="step", density = True, label = "w=1.75")

#ax0.hist(tt1, bins = xx, histtype="step", density = True, label = "w=0.25") 
#ax0.set_title('w=0.25')
#ax0.set_xlabel('Energy')
#ax0.set_ylabel('Number of states')

#ax1.hist(tt2, bins = xx, histtype="step", density = True, label = "w=0.50") 
#ax1.set_title('w=0.50')
#ax1.set_xlabel('Energy')
#ax1.set_ylabel('Number of states')

#ax2.hist(tt3, bins = xx, histtype="step", density = True, label = "w=0.75")
#ax2.set_title('w=0.75')
#ax2.set_xlabel('Energy')
#ax2.set_ylabel('Number of states')

#ax3.hist(tt4, bins = xx, histtype="step", density = True, label = "w=1.00") 
#ax3.set_title('w=1.00')
#ax3.set_xlabel('Energy')
#ax3.set_ylabel('Number of states')

#ax4.hist(tt5, bins = xx, histtype="step", density = True, label = "w=1.50")
#ax4.set_title('w=1.50')
#ax4.set_xlabel('Energy')
#ax4.set_ylabel('Number of states')

#ax5.hist(tt6, bins = xx, histtype="step", density = True, label = "w=1.25") 
#ax5.set_title('w=1.25')
#ax5.set_xlabel('Energy')
#ax5.set_ylabel('Number of states')

#ax6.hist(tt7, bins = xx, histtype="step", density = True, label = "w=1.75")
#ax6.set_title('w=1.75')
#ax6.set_xlabel('Energy')
#ax6.set_ylabel('Number of states')

#plt.hist(tt8, bins = xx, alpha=0.5, density = True, label = "w=2.00") 


plt.xlabel('Energy')
plt.ylabel('Number of states')
plt.title("Density of States, Graphene Single Layer,t'=0, Lattice size: 9216, Sample Size: 100")
plt.legend(loc='upper right')

#area = sum(np.diff(bins)*values)
# Show plot 
#fig.tight_layout()
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
from decimal import Decimal
import json
from operator import truediv
from scipy.interpolate import UnivariateSpline

plt.grid(True, which="both", ls="-",linewidth = "0.25")
#plt.grid(True, linewidth = "0.5")

#tt1= np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0.1]/Result_t[0.25].txt")
#tt2= np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0.1]/Result_t[0.50].txt")
#tt3= np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0.1]/Result_t[0.75].txt")
#tt4= np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0.1]/Result_t[1.00].txt")
#tt5= np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0.1]/Result_t[1.50].txt")
#tt1 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.25].txt")
#tt2 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.50].txt")
#tt3 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[0.75].txt")
#tt4 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.00].txt")
#tt5 = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_Bilayer_AB_Average/t4[zero]/Result_t[1.50].txt")

tt1 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[0.25].txt")
tt2 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[0.50].txt")
tt3 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[0.75].txt")
tt4 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[1.00].txt")
tt5 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[1.50].txt")
tt6 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[1.25].txt")
tt7 = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[1.75].txt")



result1=[]
i=0
while i<len(tt1):
    #print(result1[i])
    if (tt1[i]>=0 and tt1[i]<1):
        #print(tt[i])
        result1.append(tt1[i])
    i=i+1
    
    
result2=[]
i=0
while i<len(tt2):
    #print(result1[i])
    if (tt2[i]>=0 and tt2[i]<1):
        #print(tt[i])
        result2.append(tt2[i])
    i=i+1
    
    
result3=[]
i=0
while i<len(tt3):
    #print(result1[i])
    if (tt3[i]>=0 and tt3[i]<1):
        #print(tt[i])
        result3.append(tt3[i])
    i=i+1
    

result4=[]
i=0
while i<len(tt4):
    #print(result1[i])
    if (tt4[i]>=0 and tt4[i]<1):
        #print(tt[i])
        result4.append(tt4[i])
    i=i+1
        
    
result5=[]
i=0
while i<len(tt5):
    #print(result1[i])
    if (tt5[i]>=0 and tt5[i]<1):
        #print(tt[i])
        result5.append(tt5[i])
    i=i+1
    
    
    
result1 = [i for i in result1 if i != 0]
#print(result)

result2 = [i for i in result2 if i != 0]
#print(result)

result3 = [i for i in result3 if i != 0]
#print(result)

result4 = [i for i in result4 if i != 0]
#print(result)

result5 = [i for i in result5 if i != 0]
#print(result)



#print(result)

#bin for DoS
#i = 1
#xx = []
#d = 0
#num = 7
#while i<num:
#    d = d + 10**(-i)
#    xx.append(d)
#    i=i+1
#p = sorted(xx)

#p = np.logspace(start=np.log10(10**(-5)), stop=np.log10(1), num=5)
#print(p)


#i=0
#xxi=[]
#d=0
#num = 125
#while i<num:
#    d = d + 0.008
#    xxi.append(round(d,3))
#    i=i+1
#p=sorted(xxi)
#print(p)
#print("\n")

pp5=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp5)-1:
    diff = pp5[i+1]-pp5[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p5=[]
i=0
d=0
while i<len(xxi)-1:
    p5.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p5)

pp4=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp4)-1:
    diff = pp4[i+1]-pp4[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p4=[]
i=0
d=0
while i<len(xxi)-1:
    p4.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p4)

pp3=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp3)-1:
    diff = pp3[i+1]-pp3[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p3=[]
i=0
d=0
while i<len(xxi)-1:
    p3.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p3)


pp2=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp2)-1:
    diff = pp2[i+1]-pp2[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p2=[]
i=0
d=0
while i<len(xxi)-1:
    p2.append(d)
    d=d+xxi[i]
    i=i+1
#print("\n")
#print(p2)


pp1=np.logspace(np.log10(0.000000001),np.log10(1.0), 1000)
#print(pp)
i=0
xxi=[]
while i< len(pp1)-1:
    diff = pp1[i+1]-pp1[i]
    xxi.append(diff)
    i=i+1
#print(len(x))
xxi.reverse()
#print(x)
p1=[]
i=0
d=0
while i<len(xxi)-1:
    p1.append(d)
    d=d+xxi[i]
    i=i+1
#print(p1)






j=0
yy1=[]
while j<len(p1)-1:
    d1 = p1[j]
    d2 = p1[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result1 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy1.append(d)
    j=j+1
#print(yy1)

j=0
yy2=[]
while j<len(p2)-1:
    d1 = p2[j]
    d2 = p2[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result2 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy2.append(d)
    j=j+1
#print(yy)

j=0
yy3=[]
while j<len(p3)-1:
    d1 = p3[j]
    d2 = p3[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result3 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy3.append(d)
    j=j+1
#print(yy)

j=0
yy4=[]
while j<len(p4)-1:
    d1 = p4[j]
    d2 = p4[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result4 if x >= d1 and x <= d2])
    #print(d)
    #dd = d*p[j]
    yy4.append(d)
    j=j+1
#print(len(yy4))

j=0
yy5=[]
while j<len(p5)-1:
    d1 = p5[j]
    d2 = p5[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result5 if x >= d1 and x <= d2])
    #print(d)
    #dd = (d*p[j])
    yy5.append(d)
    j=j+1
#print(len(yy5))
p1=np.delete(p1,-1)
p2=np.delete(p2,-1)
p3=np.delete(p3,-1)
p4=np.delete(p4,-1)
p5=np.delete(p5,-1)
#del p[-1]
#del xx2[-1]
#del xx3[-1]
#del xx4[-1]
#del xx5[-1]

#plot and fit
#m1, b1 = np.polyfit(p1[0:29], yy1[0:29], 1)

plt.xlabel('E')
plt.ylabel(r'$\rho(E)$')
#plt.title("Density of States, t=0.1")
plt.title("Density of States, Graphene Bilayer AB, t4=t/60,M=5 Lattice Size: 7200")
#plt.scatter(xx,yy)
#plt.plot(p1[0:32], yy1[0:32], 'x', markersize='3')

#s = UnivariateSpline(p1[0:32], yy1[0:32], s=5, k=2)
#xs = np.linspace(0, 1 , 750)
#ys = s(xs)
#plt.plot(xs, ys)

########ERROR############
sample_number = 100


ii=0
f1=yy1[0:24]
lt = len(f1)
error1 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x1 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Energy_Eigenvalues_w[0.25]_M[5]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x1):
        if (x1[i]>=0 and x1[i]<1):
            result.append(x1[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p1)-1:
        d1 = p1[j]
        d2 = p1[j+1] #np.log(4+np.log(j))
        d = len([x for x in result if x >= d1 and x <= d2])
        yyi.append(d)
        j=j+1
    
    #print(yyi)
    #print(len(f))
    f2=yyi[0:24]
    error1 = error1 + (np.subtract(f1,f2))**2
    
    ii=ii+1



error1 = np.sqrt(error1)
error1 = np.true_divide(error1,math.sqrt(sample_number))
#print(error)
#print("\n")
#print(mean)
final_error1=list(map(truediv,error1,f1))
#print(final_error1)



#W=0.50
ii=0
f1=yy2[0:21]
lt = len(f1)
error2 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x2 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Energy_Eigenvalues_w[0.50]_M[5]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x2):
        if (x2[i]>=0 and x2[i]<1):
            result.append(x2[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p2)-1:
        d1 = p2[j]
        d2 = p2[j+1] #np.log(4+np.log(j))
        d = len([x for x in result if x >= d1 and x <= d2])
        yyi.append(d)
        j=j+1
    
    #print(yyi)
    #print(len(f))
    f2=yyi[0:21]
    error2 = error2 + (np.subtract(f1,f2))**2
    
    ii=ii+1



error2 = np.sqrt(error2)
error2 = np.true_divide(error2,math.sqrt(sample_number))
#print(error)
#print("\n")
#print(mean)
final_error2=list(map(truediv,error2,f1))
#print(final_error1)


#W=0.75
ii=0
f1=yy3[0:21]
lt = len(f1)
error3 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x3 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Energy_Eigenvalues_w[0.75]_M[5]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x3):
        if (x3[i]>=0 and x3[i]<1):
            result.append(x3[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p3)-1:
        d1 = p3[j]
        d2 = p3[j+1] #np.log(4+np.log(j))
        d = len([x for x in result if x >= d1 and x <= d2])
        yyi.append(d)
        j=j+1
    
    #print(yyi)
    #print(len(f))
    f2=yyi[0:21]
    error3 = error3 + (np.subtract(f1,f2))**2
    
    ii=ii+1



error3 = np.sqrt(error3)
error3 = np.true_divide(error3,math.sqrt(sample_number))
#print(error)
#print("\n")
#print(mean)
final_error3=list(map(truediv,error3,f1))
#print(final_error1)

#W=1.00
ii=0
f1=yy4[0:21]
lt = len(f2)
error4 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x4 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Energy_Eigenvalues_w[1.00]_M[5]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x4):
        if (x4[i]>=0 and x4[i]<1):
            result.append(x4[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p4)-1:
        d1 = p4[j]
        d2 = p4[j+1] #np.log(4+np.log(j))
        d = len([x for x in result if x >= d1 and x <= d2])
        yyi.append(d)
        j=j+1
    
    #print(yyi)
    #print(len(f))
    f2=yyi[0:21]
    error4 = error4 + (np.subtract(f1,f2))**2
    
    ii=ii+1



error4 = np.sqrt(error4)
error4 = np.true_divide(error4,math.sqrt(sample_number))
#print(error)
#print("\n")
#print(mean)
final_error4=list(map(truediv,error4,f1))
#print(final_error1)

#W=1.50
ii=0
f1=yy5[0:21]
lt = len(f2)
error5 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x5 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Energy_Eigenvalues_w[1.50]_M[5]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x5):
        if (x5[i]>=0 and x5[i]<1):
            result.append(x5[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p5)-1:
        d1 = p5[j]
        d2 = p5[j+1] #np.log(4+np.log(j))
        d = len([x for x in result if x >= d1 and x <= d2])
        yyi.append(d)
        j=j+1
    
    #print(yyi)
    #print(len(f))
    f2=yyi[0:21]
    error5 = error5 + (np.subtract(f1,f2))**2
    
    ii=ii+1



error5 = np.sqrt(error5)
error5 = np.true_divide(error5,math.sqrt(sample_number))
#print(error)
#print("\n")
#print(mean)
final_error5=list(map(truediv,error5,f1))
#print(final_error1)




plt.scatter(p1[4:24], yy1[4:24],color='r',zorder=1)
plt.plot(p1[4:24], yy1[4:24],color='b', zorder=2)
plt.errorbar(p1[4:24], yy1[4:24], yerr = error1[4:24],fmt='.k')


plt.scatter(p2[3:21], yy2[3:21],color='black',zorder=1)
plt.plot(p2[3:21], yy2[3:21],color='darkslategrey', zorder=2)
plt.errorbar(p2[3:21], yy2[3:21], yerr = error2[3:21],fmt='.k')


plt.scatter(p3[1:21], yy3[1:21],color='peru',zorder=1)
plt.plot(p3[1:21], yy3[1:21],color='darkblue', zorder=2)
plt.errorbar(p3[1:21], yy3[1:21], yerr = error3[1:21],fmt='.k')


plt.scatter(p4[1:21], yy4[1:21],color='c',zorder=1)
plt.plot(p4[1:21], yy4[1:21],color='m', zorder=2)
plt.errorbar(p4[1:21], yy4[1:21], yerr = error4[1:21],fmt='.k')


plt.scatter(p5[1:18], yy5[1:18],color='crimson',zorder=1)
plt.plot(p5[1:18], yy5[1:18],color='grey', zorder=2)
plt.errorbar(p5[1:18], yy5[1:18], yerr = error5[1:18],fmt='o')





#print(p3)
#print("\n")
#print(yy3)

#plot and fit
#m2, b2 = np.polyfit(p2, yy2, 1)

#plt.xlabel('E')
#plt.xlabel(r'$\rho(E)$')
#plt.title("Density of States")

#plt.scatter(xx,yy)
#plt.plot(p2[0:19], yy2[0:19], 'o', markersize='3')

#s = UnivariateSpline(p2[0:19], yy2[0:19], s=5, k=1)
#xs = np.linspace(0, 1 , 750)
#ys = s(xs)
#plt.plot(xs, ys)
#plt.plot(p2[0:23], yy2[0:23], '-o',zorder=1)


#print(p2)
#print("\n")
#print(yy2)

"""
#plot and fit
m3, b3 = np.polyfit(p5, yy3, 1)

plt.xlabel('E')
plt.ylabel(r'$\rho(E)$')
plt.title("Density of States, w = [1.5]")

#plt.scatter(xx,yy)
plt.plot(p5, yy3, '*', markersize='3')

s = UnivariateSpline(p5, yy3, s=5, k=1)
xs = np.linspace(0, 1 , 750)
ys = s(xs)
plt.plot(xs, ys)
#plot and fit
m4, b4 = np.polyfit(p5, yy4, 1)

plt.xlabel('E')
plt.xlabel(r'$\rho(E)$')
plt.title("Density of States")

#plt.scatter(xx,yy)
plt.plot(p5, yy4, 'H', markersize='3')

s = UnivariateSpline(p5, yy4, s=5, k=1)
xs = np.linspace(0, 1 , 750)
ys = s(xs)
plt.plot(xs, ys)


#plot and fit
m5, b5 = np.polyfit(p5, yy5, 1)

plt.xlabel('E')
plt.ylabel(r'$\rho(E)$')
plt.title("Density of States, Lattice size = 9216, Sample Size = 100")

#plt.scatter(xx,yy)
plt.plot(p5, yy5, 'D', markersize='3')
#print(p)
#print(yy5)
s = UnivariateSpline(p5, yy5, s=5, k=1)
xs = np.linspace(0, 1 , 10000)
ys = s(xs)
plt.plot(xs, ys)
"""

plt.legend(["w=0.25","w=0.50","w=0.75","w=1.00","w=1.50"], loc ="upper right")
plt.ylim([10**0, 90])
#plt.xlim([10**-3, 1])

#print(xx5)
plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib

import matplotlib.pyplot as plt
import numpy as np
import math

#tt = np.loadtxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_SingleLayer_Chirality_Average/t[0]/Result_t[1.75].txt")
tt=np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]_w[1.50]_1000/Energy_Eigenvalues197.txt")
#print(tt)
i=0
result=[]
while i<len(tt):
    #print(result1[i])
    if (tt[i]>=0 and tt[i]<1):
        #print(tt[i])
        result.append(tt[i])
    i=i+1
#print(result)

result = [i for i in result if i != 0]
#print(result)



i=0
xx=[]
d=0
num = 124
while i<num:
    d = d + 0.008
    xx.append(d)
    i=i+1
p=sorted(xx)

i=0
rt=[]
while i<len(p):
    x = -math.log(math.log(1/p[i])) #Dyson form
    #x = -(math.log(1/result[i])) #Gade wegner
    rt.append(x)
    i=i+1
#print(rt)
p.insert(0,0)
p.append(1)

#print(result)
test=[]
j=0
yy=[]
while j<len(p)-1:
    d1 = p[j]
    d2 = p[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result if x >= d1 and x <= d2])
    #print(d)
    test.append(d)
    dd= d1*d 
    #print(dd)
    ddd = np.log(dd)
    #print("**")
    #print(ddd)
    yy.append(ddd)
    j=j+1

#print(yy)
#print(len(yy))
#f=rt[:33]
#print(f)

#i=1
#while i<4:
#    f.pop(i)
#    yy.pop(i)
#    i=i+1
#del f[1:4]
#del yy[1:4]
#print(f)
plt.xlabel('-ln(ln(1/E))')
plt.ylabel(r'$ln(E \rho (E))$')
plt.title("Density of States,Dyson, w = 0.25, t=0.01, sample size 7200")
#plt.scatter(f,yy,s=5,c="black")
#plt.plot(f,yy)
#plt.show()



# calculate polynomial
#z = np.polyfit(f, yy, 1)
#fd = np.poly1d(z)

# calculate new x's and y's
#x_new = np.linspace(f[0], f[-1], 50)
#y_new = fd(x_new)

#del yy[-1]
#print(len(rt),len(yy))
#print(rt)
#print("\n")
#print(yy)
plt.plot(rt[0:26],yy[0:26],'x')
#plt.plot(f,yy,'x', x_new, y_new,markersize=5)
#plt.errorbar(f, yy, yerr=error_array)


#print(totalerror)
#table = np.column_stack((rt[1:27],yy[1:27],error))
#np.savetxt("/home/lucifer/IISER/Summer_2021/Energy_Eigenvalues_SingleLayer_Chirality_Average/t[0]/Dyson_w[1.75].dat",table,fmt='%.54e')

#plt.xlim([f[0]-1, f[-1] + 1 ])
plt.show()
print(test)
# Out:
# Using matplotlib backend: Qt5Agg
# [40, 27, 14, 20, 17, 11, 10, 13, 12, 10, 13, 5, 18, 11, 10, 6, 11, 9, 9, 8, 14, 11, 14, 12, 13, 6, 7, 10, 8, 10, 9, 7, 5, 6, 11, 9, 5, 11, 7, 10, 10, 9, 7, 11, 10, 9, 7, 6, 7, 6, 4, 7, 10, 9, 10, 4, 7, 9, 5, 6, 7, 3, 4, 8, 7, 8, 11, 8, 6, 9, 10, 4, 4, 6, 11, 3, 12, 8, 4, 8, 10, 7, 6, 9, 7, 8, 5, 8, 8, 8, 5, 10, 3, 2, 7, 8, 11, 5, 9, 9, 9, 8, 10, 5, 8, 8, 7, 7, 10, 10, 9, 9, 9, 4, 6, 5, 6, 7, 8, 6, 9, 4, 8, 7, 3]
# /home/lucifer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in log

# %%
# %matplotlib

import matplotlib.pyplot as plt
import numpy as np
import math
from decimal import Decimal
import json
from operator import truediv



tt = np.loadtxt("/home/lucifer/IISER/Summer_2021/t[0]_w[1.50]_1000_Average/Result_t[1.50].txt")
#print(tt)

i=0
result=[]
while i<len(tt):
    #print(result1[i])
    if (tt[i]>=0 and tt[i]<1):
        #print(tt[i])
        result.append(tt[i])
    i=i+1
#print(result)

result = [i for i in result if i != 0]
#print(result)



i=0
xx=[]
d=0
num = 124
while i<num:
    d = d + 0.008
    xx.append(d)
    i=i+1
p=sorted(xx)

i=0
rt=[]
while i<len(p):
    #x = -math.log(math.log(1/p[i])) #Dyson form
    x = -(math.log(1/p[i])) #Gade wegner
    rt.append(x)
    i=i+1
#print(rt)
p.insert(0,0)
p.append(1)

#print(result)

j=0
yy=[]
mean = []
while j<len(p)-1:
    d1 = p[j]
    d2 = p[j+1] #np.log(4+np.log(j))
    #print(d1,d2)
    #print(d1,d2)
    d = len([x for x in result if x >= d1 and x <= d2])
    #print(d)
    dd= d1*d 
    mean.append(d)
    #print(dd)
    ddd = np.log(dd)
    #print("**")
    #print(ddd)
    yy.append(ddd)
    j=j+1


plt.xlabel('-ln(ln(1/E))')
plt.ylabel(r'$ln(E \rho (E))$')
plt.title("Density of States,Dyson, w = 0.25, t=0.01, sample size 7200")


plt.plot(rt[1:27],yy[1:27],'x')



#print(totalerror)

#plt.xlim([f[0]-1, f[-1] + 1 ])
plt.show()



sample_number = 1000
ii=0
lt = len(yy)
#print(lt)
error = np.array([0]*lt)

while ii<sample_number:
    
    f = open('/home/lucifer/IISER/Summer_2021/t[0]_w[1.50]_1000/Energy_Eigenvalues'+str(ii)+'.txt','r')
    x=f.read().splitlines()
    #print(x)
    #myList = ast.literal_eval(x)
    j=0
    c=[]
    while j<len(x):
        cc=Decimal(x[j])
        #print(cc)
        c.append(cc)
        j=j+1
        
    i=0
    result=[]
    while i<len(c):
        #print(result1[i])
        if (c[i]>=0 and c[i]<1):
            #print(tt[i])
            result.append(c[i])
        i=i+1
    #print(result)


    i=0
    xx=[]
    d=0
    num = 124
    while i<num:
        d = d + 0.008
        xx.append(d)
        i=i+1
    p=sorted(xx)

    i=0
    rti=[]
    while i<len(p):
        #x = -math.log(math.log(1/p[i])) #Dyson form
        x = -(math.log(1/p[i])) #Gade wegner
        rti.append(x)
        i=i+1
    #print(rt)
    p.insert(0,0)
    p.append(1)

    #print(result)

    j=0
    yyi=[]
    sample=[]
    while j<len(p)-1:
        d1 = p[j]
        d2 = p[j+1] #np.log(4+np.log(j))
        #print(d1,d2)
        #print(d1,d2)
        d = len([x for x in result if x >= d1 and x <= d2])
        #print(d)
        dd= d1*d 
        sample.append(d)
        #print(dd)
        ddd = np.log(dd)
        #print("**")
        #print(ddd)
        yyi.append(ddd)
        j=j+1
    
    #print(mean)
    #print("\n")
    #print(sample)
    #print(yyi[1:27])
    #print(np.subtract(yyi[1:27],yy[1:27]))
    #print("\n")
    error = error + (np.subtract(sample,mean))**2

        
    ii=ii+1
#print(error)
#print(yy[1:27])
error = np.sqrt(error)
error = np.true_divide(error,math.sqrt(sample_number-1))
print(error)
print("\n")
print(mean)
final_error=list(map(truediv,error,mean))
print(final_error)
table = np.column_stack((rt[1:27],yy[1:27],final_error[1:27]))
np.savetxt("/home/lucifer/IISER/Summer_2021/t[0]_w[1.50]_1000_Average/GW_w[1.50].dat",table,fmt='%.54e')
# Out:
# Using matplotlib backend: Qt5Agg
# /home/lucifer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: RuntimeWarning: divide by zero encountered in log
# /home/lucifer/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:152: RuntimeWarning: divide by zero encountered in log
# [41.02051539 20.84027702 17.72684889 15.62546906 13.54136612 13.45709742
#  12.37449169 12.30389137 11.22670503 11.15191689 10.08816042 10.03478057
#   9.96426869  9.90131823  8.8279685   9.77815235  8.70698424  8.63815306
#   8.58182239  8.53832417  7.48882854  8.40834476  7.36965794  7.29063286
#   8.23225495  7.20325252  7.13652815  7.05018661  7.03588468  6.9379329
#   6.9315313   5.92866003  6.84885243  5.80424345  6.71960592  5.69338819
#   5.60988652  6.56560521  5.53679565  5.46515276  6.41231748  5.39680961
#   5.31735425  5.29783473  5.3080668   5.20659242  5.17913245  5.16406606
#   4.03955052  5.05788201  4.96367586  4.95198196  3.97632289  4.87092717
# ...

# %%
# %matplotlib

import matplotlib.pyplot as plt
import numpy as np
import math
from decimal import Decimal
import json
from operator import truediv

from scipy.optimize import curve_fit

plt.grid(True, which="both", ls="-",linewidth = "0.25")


tt=np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/AA_AB_Chirality_Layer/Graphene_Bilayer_AA/Result_t[0.75].txt")
#tt = np.loadtxt("/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_OnSite_Potential/Graphene_Bilayer_AB/Result_t[1.75].txt")
#tt = np.loadtxt("IISER/SEM_7/Semester_Project/Graphene_SingleLayer_1000_Samples/Result_t[0.50].txt")
#print(tt)

i=0
result=[]
while i<len(tt):
    #print(result1[i])
    if (tt[i]>=0):# and tt[i]<1):
        #print(tt[i])
        result.append(tt[i])
    i=i+1
#print(result)

result = [i for i in result if i != 0]
#print(result)

i=0
xx=[]
d=0
num = 125*6
while i<num:
    d = d + 0.008
    xx.append(round(d,3))
    #xx.append(round(d,3))
    i=i+1
p=sorted(xx)
#print(p)
#print("\n")


xxi=[]
i=0
while i<len(p):
    d=math.log10(1/p[i])
    xxi.append(d)
    i=i+1
#print(xxi)
#print("\n") 

xxi.reverse()
i=0
while i<len(xxi):
    #print(math.log10(1/0.8))
    if (xxi[i] >= math.log10(1/0.8)):
        counter = i
        break
    i=i+1

print(counter)
#print(xxi)
#del p[0:counter]
print(xxi[counter])
    

j=0
yy=[]
mean = []
while j<len(p)-1:
    d1 = p[j]
    d2 = p[j]+1
    #print(d1,d2)
    d = len([x for x in result if x <= d1])
    #print(d)
    yy.append(d)
    j=j+1

del xxi[-1]
#print(len(yy))
#del xxi[-1]
#xxi.reverse()
yy.reverse()
plt.xlabel(r'$\Gamma$')
plt.ylabel(r'$N(\Gamma)$')
plt.title("Density of States, Graphene AA Bilayer, w = 0.75, t0=0, Lattice Size: 7200, Sample Size: 100")

plt.scatter(xxi,yy, s=1.75,c='blue')
#plt.show()
#print(xxi)
#print("\n")
#print(yy)
#table = np.column_stack((xxi,yy))
#np.savetxt("/home/lucifer/IISER/Summer_2021/t[0]_w[1.50]_1000_Average/Test_w[1.50].dat",table,fmt='%.54e')

#############Gade Wegner#######################
#counter=0
x_min = xxi[counter] 
x_max = 5                                #min/max values for x axis
x_fit = np.linspace(x_min, x_max, 100)   #range of x values used for the fit function

def test(x, B,C):
    y = B*(np.power(x,1/3))*(np.exp(-C*np.power(x,2/3))) #Gade Wegner form
    #y = A*(np.power(x,-B)) +C
    return y

parameters, covariance = curve_fit(test, xxi[counter:], yy[counter:])
#print(xxi[counter], yy[counter])

#fit_A = parameters[0]
fit_B = parameters[0]
fit_C = parameters[1]


fit_y = test(x_fit, fit_B, fit_C)

plt.plot(x_fit, fit_y, '--', color ='red', label ="optimized data")
#print(fit_y)
"""
#############Dyson#######################

def test1(x, A1,B1):
    y = A1*(np.power(x,-B1))  #Dyson form
    return y

parameters1, covariance1 = curve_fit(test, xxi[counter:], yy[counter:])


fit_A1 = parameters1[0]
fit_B1 = parameters1[1]
#fit_C = parameters[2]

fit_y = test1(xxi[counter:], fit_A1, fit_B1)

plt.plot(xxi[counter:], fit_y, '--', color ='blue', label ="optimized data")
"""




########ERROR############
sample_number = 100

#print(yy)
ii=0
lt = len(yy)
error1 = np.array([0]*lt)
#print(len(yy1[0:24]))
while ii<sample_number:
    
    x1 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/AA_AB_Chirality_Layer/Graphene_Bilayer_AA/Energy_Eigenvalues_w[0.75]/Energy_Eigenvalues'+str(ii)+'.txt')
    #x1 = np.loadtxt('/home/lucifer/IISER/SEM_7/Semester_Project/Graphene_Bilayer_AA/Energy_Eigenvalues_w[0.50]/Energy_Eigenvalues'+str(ii)+'.txt')
       
    i=0
    result=[]
    while i<len(x1):
        if (x1[i]>=0 and x1[i]<1):
            result.append(x1[i])
        i=i+1
    #print(len(result))
    
    j=0
    yyi=[]
    while j<len(p)-1:
        d1 = p[j]
        d2 = p[j]+1 #np.log(4+np.log(j))
        d = len([x for x in result if x <= d1])
        yyi.append(d)
        j=j+1
    yyi.reverse()
    #print(yyi)
    #print(len(f))
    error1 = error1 + (np.subtract(yy,yyi))**2
    
    ii=ii+1


#print(yy)
error1 = np.sqrt(error1)
error1 = np.true_divide(error1,math.sqrt(sample_number))
#error1[-1] = 0
#error1[-2] = 0
#error1[-3] = 0
#print(error1)
#print("\n")
#print(mean)
final_error1=list(map(truediv,error1,yy))
#print(final_error1)

plt.errorbar(xxi, yy,yerr = error1,fmt='.k',markersize=5,capsize=4,elinewidth=1.5,alpha=0.5)

plt.legend([r'f(x)=A.${\Gamma}^{\frac{1}{3}}e^{-C{\Gamma}^{\frac{2}{3}}}$',r'$N(\Gamma)$','Error'], loc ="upper right")
#plt.ylim([10**-1, 10**4])
#plt.xlim([10**-3, 1])


#plt.ylim([10**-1, 10**4])
plt.xlim([4*10**-2, 6])

plt.xscale('log')
plt.yscale('log')
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg
# 650
# 0.09691001300805642

# %%
# Out:
# 1.6.2
